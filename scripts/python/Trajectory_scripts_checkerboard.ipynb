# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import patches
from scipy.spatial.transform import Rotation as R
# import gtsam

# %%
###################################################################
#####  PROCESS the drift error from checkerboard              ##### 
###################################################################
import numpy as np
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import patches
from scipy.spatial.transform import Rotation as R
import cv2

# %%
def draw(img, corners, imgpts):
    corners = corners.astype(np.int32)
    imgpts = imgpts.astype(np.int32)
    corner = tuple(corners[0].ravel())
    img = cv2.line(img, corner, tuple(imgpts[0].ravel()), (0,0,255), 5)
    img = cv2.line(img, corner, tuple(imgpts[1].ravel()), (0,255,0), 5)
    img = cv2.line(img, corner, tuple(imgpts[2].ravel()), (255,0,0), 5)
    return img

# %%
def getPoseFromChessBoard(img_inp, k, dist, squarSize):
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
    objp = np.zeros((16*9,3), np.float32)
    objp[:,:2] = np.mgrid[0:16,0:9].T.reshape(-1,2)
    objp = objp * squarSize
    axis = np.float32([[3,0,0], [0,3,0], [0,0,-3]]).reshape(-1,3)
    axis = axis * squarSize
    T_ci = np.zeros((4,4), np.float64)
    ## detect chesssboard
    ret, corners = cv2.findChessboardCorners(img_inp, (16,9),None, cv2.CALIB_CB_FAST_CHECK)
   
    if ret == True:
        print("corners found")
        corners2 = cv2.cornerSubPix(img_inp,corners,(11,11),(-1,-1),criteria)
        # Find the rotation and translation vectors.
        _,rvecs, tvecs, inliers = cv2.solvePnPRansac(objp, corners2, k, dist)
        rot_mat, _ = cv2.Rodrigues(rvecs)
        ## get pose WRT chessboard T_ci
        T_ic = np.vstack((np.hstack((rot_mat, tvecs)), np.array([0, 0, 0, 1])))
        T_ci = np.linalg.inv(T_ic)
        # project 3D points to image plane
        imgpts, jac = cv2.projectPoints(axis, rvecs, tvecs, k, dist)
        cv2.drawChessboardCorners(img_inp, (16,9), corners2, ret)
        img = cv2.cvtColor(img_inp,cv2.COLOR_GRAY2RGB)
        img = draw(img,corners2,imgpts)
#         cv2.imshow('img',img)
#         cv2.waitKey(20)
    else:
        print("Corners not found")
    return T_ci

# %%
def computeError(df_traj, tStamp, k, dist, squareSize, patternSize, T_c0=np.eye(4)):
    img_gray = cv2.imread(os.path.join(data_path,str(tStamp)+".jpg"), 0)
    #clahe = cv2.createCLAHE(clipLimit = 5)
    #img_gray = clahe.apply(img_gray)
    T_ci_gt = getPoseFromChessBoard(img_gray, k, dist, squareSize)
    if np.linalg.norm(T_ci_gt) == 0:
        #print("Checkerboard not found")
        return -1, -1
    t =round(tStamp*1e-9, 6)
    print("Image : ", tStamp) 
    ind_df = df_traj[0].sub(t).abs().idxmin()
    
    #ind_df = (df_traj[0].tolist().index(t))
    print("index : ", ind_df)
    quat = np.array(df_traj.iloc[ind_df, 4:8])
    rot = R.from_quat(quat).as_matrix()
    trans = np.array(df_traj.iloc[ind_df,1:4]).reshape(3,1)
    T_0i = np.vstack((np.hstack((rot, trans)), np.array([0,0,0,1])))
    ## In Tum trajectory we have T_0i, pose WRT start, 
    ## GT = T_ci, expected T_ci^ = T_c0 * T_0i=
    print("GT Pose: ")
    print(T_ci_gt)
    if T_ci_gt[3,3] > 2.0 :
        print("calibrationj board is too far. estimate wont be accurate")
        return -1, -1
    print("expected Pose Traj: ")
    T_ci_exp = T_c0 @ T_0i
    print(T_ci_exp)
    #find delta pose
    deltapose = np.linalg.inv(T_ci_exp) @ T_ci_gt
    rotvec_cv,_ = cv2.Rodrigues(deltapose[0:3,0:3])
    trans_error = np.linalg.norm(T_ci_exp[0:3, 3] - T_ci_gt[0:3, 3])
    rot_error = np.rad2deg(np.linalg.norm(rotvec_cv))
    print("translation error: ",trans_error, )
    print("rotation error in degrees: ", rot_error)
    return trans_error, rot_error

# %%
def main(data_path,traj_path, k, dist, first_stamp ):
    



    ## read the tum format trajectory file
    df = pd.read_csv(traj_path, header=None,skipinitialspace=True, sep=' ')
    image_path = os.path.join(data_path,str(first_stamp)+".jpg")
    print("image_path" , image_path)
    img_first = cv2.imread(os.path.join(data_path,str(first_stamp)+".jpg"), 0)

    T_cs = getPoseFromChessBoard(img_first, k, dist, 0.081)
    # print(T_cs)

    computeError(df, first_stamp, k, dist, 0.081, (9,9), T_cs)

    imgnames = os.listdir(data_path)
    imgnames.sort()
    imgstamps = np.array([ float(img[:-4])*1e-9 for img in imgnames])



    avg_trans_e = 0
    avg_rot_e = 0
    cnt =0


    for stamp in df[0]:
        if stamp > (first_stamp*1e-9 + 170):
            print("STamp:",stamp)
            diffs = np.absolute(imgstamps - stamp)
            image_index = diffs.argmin()
            trans_e, rot_e = computeError(df, int(imgnames[image_index][:-4]), k, dist, 0.081, (9,9), T_cs)
            if trans_e != -1 and rot_e != -1:
                avg_trans_e = avg_trans_e + trans_e
                avg_rot_e = avg_rot_e + rot_e
                cnt = cnt +1
    print("Average translation error : ", avg_trans_e/cnt)
    print("Average rotational error : ", avg_rot_e/cnt)

# %%
# isec_ground1

data_path="/media/neural/pushyami_disk/oldneufr_data/04_21_2022_isec_curry/ISEC_Ground1/cam1"


k = np.array([[890.3108042354397, 0, 371.6746843591246],
             [0, 890.8454719023792, 275.10004314234504],
            [0, 0, 1]])

dist = np.array([-0.21075936736896436, 0.16323979280198103, 5.060027981629671e-06, 8.671705366115946e-05])
first_stamp = 1650574403355778934

traj_path_15 = "/home/neural/multicamSLAM/results/isec_ground1/traj_15.txt"
traj_path_1 = "/home/neural/multicamSLAM/results/isec_ground1/traj_1.txt"
traj_path_156 = "/home/neural/multicamSLAM/results/isec_ground1/traj_156.txt"
traj_path_015 = "/home/neural/multicamSLAM/results/isec_ground1/traj_015.txt"

# main(data_path,traj_path_15, k, dist, first_stamp )

# main(data_path,traj_path_1, k, dist, first_stamp )

# main(data_path,traj_path_156, k, dist, first_stamp )

# main(data_path,traj_path_015, k, dist, first_stamp )
# Out:
# image_path /media/neural/pushyami_disk/oldneufr_data/04_21_2022_isec_curry/ISEC_Ground1/cam1/1650574403355778934.jpg
# corners found
# corners found
# Image :  1650574403355778934
# index :  0
# GT Pose:
# [[ 0.99323903  0.00404174 -0.11601678  1.19108321]
#  [-0.01663858  0.99403162 -0.107816    0.32351058]
#  [ 0.11488858  0.10901741  0.98737825 -3.84084279]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.99323903  0.00404174 -0.11601678  1.19108321]
#  [-0.01663858  0.99403162 -0.107816    0.32351058]
#  [ 0.11488858  0.10901741  0.98737825 -3.84084279]
#  [ 0.          0.          0.          1.        ]]
# translation error:  0.0
# rotation error in degrees:  0.0
# STamp: 1650574573.402195
# Corners not found
# STamp: 1650574573.703099
# Corners not found
# STamp: 1650574574.153624
# Corners not found
# STamp: 1650574574.603385
# Corners not found
# STamp: 1650574575.053067
# Corners not found
# STamp: 1650574575.502898
# Corners not found
# STamp: 1650574575.802951
# Corners not found
# STamp: 1650574576.252823
# Corners not found
# STamp: 1650574576.703139
# Corners not found
# STamp: 1650574577.152679
# Corners not found
# STamp: 1650574577.603639
# Corners not found
# STamp: 1650574578.203416
# Corners not found
# STamp: 1650574578.804058
# Corners not found
# STamp: 1650574579.25328
# Corners not found
# STamp: 1650574579.703299
# Corners not found
# STamp: 1650574580.30366
# Corners not found
# STamp: 1650574580.954521
# Corners not found
# STamp: 1650574581.405071
# Corners not found
# STamp: 1650574582.306131
# Corners not found
# STamp: 1650574583.205641
# Corners not found
# STamp: 1650574584.106561
# Corners not found
# STamp: 1650574585.006554
# Corners not found
# STamp: 1650574585.906139
# Corners not found
# STamp: 1650574586.805606
# Corners not found
# STamp: 1650574587.705887
# Corners not found
# STamp: 1650574588.305876
# Corners not found
# STamp: 1650574588.905718
# Corners not found
# STamp: 1650574589.507143
# Corners not found
# STamp: 1650574590.405909
# Corners not found
# STamp: 1650574591.155908
# Corners not found
# STamp: 1650574591.906604
# Corners not found
# STamp: 1650574592.806563
# Corners not found
# STamp: 1650574593.406242
# Corners not found
# STamp: 1650574593.856545
# Corners not found
# STamp: 1650574594.156797
# Corners not found
# STamp: 1650574594.605691
# Corners not found
# STamp: 1650574595.055673
# Corners not found
# STamp: 1650574595.506234
# Corners not found
# STamp: 1650574595.95643
# Corners not found
# STamp: 1650574596.405802
# Corners not found
# STamp: 1650574596.855924
# Corners not found
# STamp: 1650574597.756149
# Corners not found
# STamp: 1650574598.656702
# Corners not found
# STamp: 1650574599.255964
# Corners not found
# STamp: 1650574599.85715
# Corners not found
# STamp: 1650574600.306093
# Corners not found
# STamp: 1650574600.755864
# Corners not found
# STamp: 1650574601.055739
# Corners not found
# STamp: 1650574601.505882
# Corners not found
# STamp: 1650574601.956048
# Corners not found
# STamp: 1650574602.406582
# Corners not found
# STamp: 1650574602.705751
# Corners not found
# STamp: 1650574603.156268
# Corners not found
# STamp: 1650574603.606585
# Corners not found
# STamp: 1650574603.906626
# Corners not found
# STamp: 1650574604.206148
# Corners not found
# STamp: 1650574604.506179
# Corners not found
# STamp: 1650574604.805911
# Corners not found
# STamp: 1650574605.106426
# Corners not found
# STamp: 1650574605.556194
# corners found
# Image :  1650574605556194048
# index :  290
# GT Pose:
# [[ 9.82893956e-01  1.05003869e-03  1.84169402e-01  7.48149230e-01]
#  [ 1.88297718e-02  9.94170663e-01 -1.06160884e-01  3.20959608e-01]
#  [-1.83207290e-01  1.07812759e-01  9.77144564e-01 -3.77398966e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 9.95393096e-01  4.48117396e-04  9.58769186e-02  1.81656954e+00]
#  [ 9.90706559e-03  9.94155548e-01 -1.07501610e-01 -6.90269391e-03]
#  [-9.53647439e-02  1.07956219e-01  9.89571130e-01 -4.72025821e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# translation error:  1.4643905963109483
# rotation error in degrees:  5.111038776098637
# STamp: 1650574605.856101
# corners found
# Image :  1650574605856100937
# index :  291
# GT Pose:
# [[ 9.91625483e-01  3.68605954e-03  1.29094210e-01  7.75940931e-01]
#  [ 1.05384633e-02  9.93949561e-01 -1.09330744e-01  3.16797583e-01]
#  [-1.28716133e-01  1.09775607e-01  9.85586867e-01 -3.70331600e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 9.99161951e-01  2.75187699e-03  4.08389820e-02  1.83415297e+00]
#  [ 1.72440032e-03  9.94021628e-01 -1.09169725e-01 -1.44814536e-02]
#  [-4.08952530e-02  1.09148658e-01  9.93183844e-01 -4.65912668e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# translation error:  1.4639441841788985
# rotation error in degrees:  5.077269919127915
# STamp: 1650574606.1559
# corners found
# Image :  1650574606155899297
# index :  292
# GT Pose:
# [[ 9.97990079e-01  5.89277207e-03  6.30957797e-02  8.00233481e-01]
#  [ 1.12176176e-03  9.93868330e-01 -1.10564394e-01  3.02286401e-01]
#  [-6.33604280e-02  1.10412947e-01  9.91864122e-01 -3.63445165e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 0.9996826   0.0048272  -0.02472651  1.84998614]
#  [-0.00757261  0.99366001 -0.11217149 -0.02033558]
#  [ 0.02402827  0.11232313  0.99338117 -4.60026369]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.4624836709737277
# rotation error in degrees:  5.0354561214667255
# STamp: 1650574606.457015
# corners found
# Image :  1650574606457014541
# index :  293
# GT Pose:
# [[ 9.99974662e-01  6.86740828e-03  1.87455464e-03  8.18580741e-01]
#  [-6.61506501e-03  9.93720147e-01 -1.11698302e-01  2.96631856e-01]
#  [-2.62986055e-03  1.11683071e-01  9.93740396e-01 -3.56212739e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 0.99631893  0.00539106 -0.08555423  1.86141179]
#  [-0.0150288   0.99354819 -0.11241054 -0.02778154]
#  [ 0.08439624  0.11328253  0.98997189 -4.53916784]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.4653834621670618
# rotation error in degrees:  5.016368651452317
# STamp: 1650574606.906551
# corners found
# Image :  1650574606906550964
# index :  294
# GT Pose:
# [[ 0.997569    0.00804978 -0.06921914  0.83409457]
#  [-0.01585835  0.99346703 -0.11301225  0.28323984]
#  [ 0.06785721  0.11383522  0.99117957 -3.44921193]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.98784618  0.00600043 -0.15531877  1.86478503]
#  [-0.02396542  0.99318554 -0.11405327 -0.03743249]
#  [ 0.15357599  0.11638936  0.98125834 -4.44021672]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.465347758722239
# rotation error in degrees:  4.968712691849362
# STamp: 1650574607.356165
# corners found
# Image :  1650574607356165316
# index :  295
# GT Pose:
# [[ 0.98961655  0.00617316 -0.14360009  0.84344537]
#  [-0.02257276  0.99335484 -0.11285671  0.26943233]
#  [ 0.14194916  0.11492632  0.98317973 -3.33602199]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 9.73662131e-01  3.61857140e-03 -2.27967015e-01  1.86426323e+00]
#  [-3.02798427e-02  9.93069157e-01 -1.13563993e-01 -5.08851335e-02]
#  [ 2.25976072e-01  1.17475765e-01  9.67023402e-01 -4.34316808e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# translation error:  1.469358920616063
# rotation error in degrees:  4.924766660548331
# Average translation error :  1.46515143216149
# Average rotational error :  5.022268803423882

# %%
# curry

data_path="/media/neural/pushyami_disk/oldneufr_data/04_21_2022_isec_curry/Curry_center/cam1"


k = np.array([[890.3108042354397, 0, 371.6746843591246],
             [0, 890.8454719023792, 275.10004314234504],
            [0, 0, 1]])

dist = np.array([-0.21075936736896436, 0.16323979280198103, 5.060027981629671e-06, 8.671705366115946e-05])
first_stamp = 1650576195148245580

# traj_path_15 = "/home/neural/multicamSLAM/results/isec_ground1/traj_15.txt"
# traj_path_1 = "/home/neural/multicamSLAM/results/isec_ground1/traj_1.txt"
# traj_path_156 = "/home/neural/multicamSLAM/results/isec_ground1/traj_156.txt"
traj_path_015 = "/home/neural/multicamSLAM/results/curry/traj_015.txt"

# main(data_path,traj_path_15, k, dist, first_stamp )

# main(data_path,traj_path_1, k, dist, first_stamp )

# main(data_path,traj_path_156, k, dist, first_stamp )

main(data_path,traj_path_015, k, dist, first_stamp )
# Out:
# image_path /media/neural/pushyami_disk/oldneufr_data/04_21_2022_isec_curry/Curry_center/cam1/1650576195148245580.jpg
# corners found
# corners found
# Image :  1650576195148245580
# index :  0
# GT Pose:
# [[ 9.99934217e-01 -1.06614485e-02  4.23027904e-03  5.37625666e-01]
#  [ 1.14191038e-02  9.60033864e-01 -2.79650827e-01  1.12188129e+00]
#  [-1.07972825e-03  2.79680736e-01  9.60092454e-01 -4.30040204e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 9.99936295e-01 -1.06346725e-02  3.78273530e-03  5.37533851e-01]
#  [ 1.12683133e-02  9.59999139e-01 -2.79776121e-01  1.12185570e+00]
#  [-6.56095204e-04  2.79800923e-01  9.60057818e-01 -4.30040947e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# translation error:  9.560303885336382e-05
# rotation error in degrees:  0.026744555745663375
# STamp: 1650576365.352466
# Corners not found
# STamp: 1650576366.252385
# Corners not found
# STamp: 1650576367.150114
# Corners not found
# STamp: 1650576367.600009
# Corners not found
# STamp: 1650576368.050291
# Corners not found
# STamp: 1650576368.501935
# Corners not found
# STamp: 1650576368.952687
# Corners not found
# STamp: 1650576369.702245
# Corners not found
# STamp: 1650576370.600555
# Corners not found
# STamp: 1650576371.498191
# Corners not found
# STamp: 1650576372.247438
# Corners not found
# STamp: 1650576372.997725
# Corners not found
# STamp: 1650576373.748306
# Corners not found
# STamp: 1650576374.648189
# Corners not found
# STamp: 1650576374.948247
# Corners not found
# STamp: 1650576375.248475
# Corners not found
# STamp: 1650576376.148195
# Corners not found
# STamp: 1650576376.898925
# Corners not found
# STamp: 1650576377.648953
# Corners not found
# STamp: 1650576378.099807
# Corners not found
# STamp: 1650576378.84865
# Corners not found
# STamp: 1650576379.599549
# Corners not found
# STamp: 1650576380.498643
# Corners not found
# STamp: 1650576381.398949
# Corners not found
# STamp: 1650576382.348873
# Corners not found
# STamp: 1650576383.098497
# Corners not found
# STamp: 1650576383.548664
# Corners not found
# STamp: 1650576384.298538
# Corners not found
# STamp: 1650576384.748036
# Corners not found
# STamp: 1650576388.498331
# corners found
# Image :  1650576388498330886
# index :  264
# GT Pose:
# [[ 0.95943609 -0.01381224 -0.28158765  1.03149556]
#  [-0.06618806  0.95984803 -0.27260027  1.23063296]
#  [ 0.27404657  0.28018028  0.91999863 -4.6423223 ]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.94960314 -0.01593456 -0.31304946 -0.537688  ]
#  [-0.07407943  0.95900746 -0.27352682  1.24967841]
#  [ 0.3045753   0.28293246  0.90949608 -3.76598116]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.7974074617846414
# rotation error in degrees:  1.902426561170117
# STamp: 1650576389.848011
# corners found
# Image :  1650576389848010828
# index :  265
# GT Pose:
# [[ 0.9745673  -0.01188931 -0.2237794   0.94711571]
#  [-0.05170166  0.95972229 -0.27615223  1.16135084]
#  [ 0.21804934  0.2806987   0.93469927 -4.41500798]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.96623127 -0.0137148  -0.25731117 -0.61995068]
#  [-0.06048734  0.95860782 -0.27823071  1.1879116 ]
#  [ 0.25047637  0.28439928  0.92540728 -3.55147029]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.7894412214790434
# rotation error in degrees:  1.9978675745262733
# STamp: 1650576390.147872
# corners found
# Image :  1650576390147871685
# index :  266
# GT Pose:
# [[ 0.99241561 -0.00951822 -0.12255881  0.89766551]
#  [-0.02571609  0.95886277 -0.28270279  1.11655021]
#  [ 0.12020791  0.28371039  0.95134561 -4.29565139]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.98757935 -0.01127671 -0.15671587 -0.67440746]
#  [-0.03459193  0.95734311 -0.28687553  1.1505676 ]
#  [ 0.15326587  0.28873346  0.9450622  -3.41860546]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.8004944307022464
# rotation error in degrees:  2.0051394662660194
# STamp: 1650576391.497773
# corners found
# Image :  1650576391497773158
# index :  267
# GT Pose:
# [[ 0.99639893 -0.01017034 -0.08417683  0.85351797]
#  [-0.01442571  0.95797163 -0.28650001  1.00898512]
#  [ 0.08355282  0.28668262  0.95437519 -3.92896159]
#  [ 0.          0.          0.          1.        ]]
# expected Pose Traj:
# [[ 0.99289067 -0.01155842 -0.11846735 -0.73428131]
#  [-0.0237254   0.95608508 -0.29212742  1.0451626 ]
#  [ 0.1166414   0.29286127  0.94901373 -3.05975327]
#  [ 0.          0.          0.          1.        ]]
# translation error:  1.8105077979352449
# rotation error in degrees:  2.0150752607733327
# Average translation error :  1.799462727975294
# Average rotational error :  1.9801272156839356

# %%
# isec_ground2

data_path="/media/neural/pushyami_disk/oldneufr_data/04_14_2022_isec_lab_ground/ISEC_Ground2/cam1"


k = np.array([[890.3108042354397, 0, 371.6746843591246],
             [0, 890.8454719023792, 275.10004314234504],
            [0, 0, 1]])

dist = np.array([-0.21075936736896436, 0.16323979280198103, 5.060027981629671e-06, 8.671705366115946e-05])
first_stamp = 1649979690238438035

traj_path_15 = "/home/neural/multicamSLAM/results/isec_ground1/traj_15.txt"
traj_path_1 = "/home/neural/multicamSLAM/results/isec_ground1/traj_1.txt"
traj_path_156 = "/home/neural/multicamSLAM/results/isec_ground1/traj_156.txt"
traj_path_015 = "/home/neural/multicamSLAM/results/isec_ground2/traj_015.txt"

# main(data_path,traj_path_15, k, dist, first_stamp )

# main(data_path,traj_path_1, k, dist, first_stamp )

# main(data_path,traj_path_156, k, dist, first_stamp )

main(data_path,traj_path_015, k, dist, first_stamp )
# Out:
# image_path /media/neural/pushyami_disk/oldneufr_data/04_14_2022_isec_lab_ground/ISEC_Ground2/cam1/1649979690238438035.jpg
# corners found
# corners found
# Image :  1649979690238438035
# index :  0
# GT Pose:
# [[ 9.83036455e-01  4.48922014e-03  1.83355323e-01 -3.95649201e-01]
#  [-4.23046440e-03  9.99989427e-01 -1.80235810e-03 -7.37243429e-02]
#  [-1.83361476e-01  9.96105556e-04  9.83045053e-01 -5.39168048e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# expected Pose Traj:
# [[ 9.83067520e-01  4.50323408e-03  1.83188349e-01 -3.95640606e-01]
#  [-4.23644394e-03  9.99989319e-01 -1.84769144e-03 -7.37325998e-02]
#  [-1.83194713e-01  1.04033828e-03  9.83076098e-01 -5.39155569e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# translation error:  0.00012535272335282996
# rotation error in degrees:  0.010076785714937905
# STamp: 1649979861.087118
# Corners not found
# STamp: 1649979861.687124
# Corners not found
# STamp: 1649979862.737607
# Corners not found
# STamp: 1649979863.636877
# Corners not found
# STamp: 1649979864.536696
# Corners not found
# STamp: 1649979865.437774
# Corners not found
# STamp: 1649979866.337394
# Corners not found
# STamp: 1649979867.237665
# Corners not found
# STamp: 1649979868.137356
# Corners not found
# STamp: 1649979869.037824
# Corners not found
# STamp: 1649979869.487422
# Corners not found
# STamp: 1649979870.387291
# Corners not found
# STamp: 1649979871.286321
# Corners not found
# STamp: 1649979872.186662
# Corners not found
# STamp: 1649979872.637478
# Corners not found
# STamp: 1649979873.387878
# Corners not found
# STamp: 1649979874.287568
# Corners not found
# STamp: 1649979875.188662
# Corners not found
# STamp: 1649979876.087407
# Corners not found
# STamp: 1649979876.837822
# Corners not found
# STamp: 1649979877.736906
# Corners not found
# STamp: 1649979878.937743
# Corners not found
# STamp: 1649979879.687291
# Corners not found
# STamp: 1649979880.13759
# Corners not found
# STamp: 1649979881.037807
# Corners not found
# STamp: 1649979881.337738
# Corners not found
# STamp: 1649979881.786988
# Corners not found
# STamp: 1649979882.386873
# Corners not found
# STamp: 1649979882.888478
# Corners not found
# STamp: 1649979883.337449
# Corners not found
# STamp: 1649979883.637057
# Corners not found
# STamp: 1649979883.936995
# Corners not found
# STamp: 1649979884.237075
# Corners not found
# STamp: 1649979884.536574
# Corners not found
# STamp: 1649979884.837446
# Corners not found
# STamp: 1649979885.286081
# Corners not found
# STamp: 1649979885.737505
# Corners not found
# STamp: 1649979886.637679
# Corners not found
# STamp: 1649979887.387522
# Corners not found
# STamp: 1649979888.287202
# Corners not found
# STamp: 1649979889.188258
# Corners not found
# STamp: 1649979890.087766
# Corners not found
# STamp: 1649979890.987299
# Corners not found
# STamp: 1649979891.887052
# Corners not found
# STamp: 1649979892.788301
# Corners not found
# STamp: 1649979893.68678
# Corners not found
# STamp: 1649979894.588017
# Corners not found
# STamp: 1649979894.887232
# Corners not found
# STamp: 1649979895.187991
# Corners not found
# STamp: 1649979895.486235
# Corners not found
# STamp: 1649979895.787712
# Corners not found
# STamp: 1649979896.087097
# Corners not found
# STamp: 1649979896.237468
# Corners not found
# STamp: 1649979896.537384
# Corners not found
# STamp: 1649979896.98743
# Corners not found
# STamp: 1649979897.88759
# Corners not found
# STamp: 1649979898.787932
# Corners not found
# STamp: 1649979899.08792
# Corners not found
# STamp: 1649979899.387854
# Corners not found
# STamp: 1649979900.287043
# Corners not found
# STamp: 1649979901.186849
# Corners not found
# STamp: 1649979902.087945
# Corners not found
# STamp: 1649979902.987111
# Corners not found
# STamp: 1649979903.587423
# Corners not found
# STamp: 1649979904.487799
# Corners not found
# STamp: 1649979905.388406
# Corners not found
# STamp: 1649979906.287811
# Corners not found
# STamp: 1649979906.887009
# Corners not found
# STamp: 1649979907.337707
# Corners not found
# STamp: 1649979907.637143
# Corners not found
# STamp: 1649979907.937774
# Corners not found
# STamp: 1649979908.385903
# Corners not found
# STamp: 1649979908.687769
# Corners not found
# STamp: 1649979908.987521
# Corners not found
# STamp: 1649979909.439001
# Corners not found
# STamp: 1649979909.887266
# Corners not found
# STamp: 1649979910.186872
# Corners not found
# STamp: 1649979910.487618
# Corners not found
# STamp: 1649979911.537583
# Corners not found
# STamp: 1649979912.437951
# Corners not found
# STamp: 1649979913.337727
# Corners not found
# STamp: 1649979914.08789
# Corners not found
# STamp: 1649979914.538162
# Corners not found
# STamp: 1649979915.038097
# Corners not found
# STamp: 1649979915.487077
# Corners not found
# STamp: 1649979915.937897
# Corners not found
# STamp: 1649979916.537695
# Corners not found
# STamp: 1649979917.738003
# Corners not found
# STamp: 1649979918.786365
# Corners not found
# STamp: 1649979919.837661
# Corners not found
# STamp: 1649979921.037809
# Corners not found
# STamp: 1649979921.637371
# Corners not found
# STamp: 1649979922.537819
# Corners not found
# STamp: 1649979923.137509
# Corners not found
# STamp: 1649979923.8877
# Corners not found
# STamp: 1649979924.937389
# Corners not found
# STamp: 1649979925.537682
# Corners not found
# STamp: 1649979925.987196
# Corners not found
# STamp: 1649979926.587285
# Corners not found
# STamp: 1649979927.637178
# Corners not found
# STamp: 1649979928.387933
# Corners not found
# STamp: 1649979928.838211
# Corners not found
# STamp: 1649979929.287276
# Corners not found
# STamp: 1649979929.737286
# Corners not found
# STamp: 1649979930.187165
# Corners not found
# STamp: 1649979930.938455
# Corners not found
# STamp: 1649979932.137767
# Corners not found
# STamp: 1649979934.537935
# Corners not found
# STamp: 1649979934.687807
# Corners not found
# STamp: 1649979934.837196
# Corners not found
# STamp: 1649979934.98737
# Corners not found
# STamp: 1649979935.138136
# Corners not found
# STamp: 1649979935.437441
# Corners not found
# STamp: 1649979935.737649
# Corners not found
# STamp: 1649979936.337284
# Corners not found
# STamp: 1649979937.23784
# Corners not found
# STamp: 1649979939.337244
# Corners not found
# STamp: 1649979939.936212
# Corners not found
# STamp: 1649979940.387427
# Corners not found
# STamp: 1649979940.837063
# Corners not found
# STamp: 1649979941.13765
# Corners not found
# STamp: 1649979941.588924
# Corners not found
# STamp: 1649979941.887778
# Corners not found
# STamp: 1649979942.186843
# Corners not found
# STamp: 1649979942.486804
# Corners not found
# STamp: 1649979942.787158
# Corners not found
# STamp: 1649979943.088835
# Corners not found
# STamp: 1649979943.387499
# Corners not found
# STamp: 1649979943.687223
# Corners not found
# STamp: 1649979943.988504
# Corners not found
# STamp: 1649979945.03821
# Corners not found
# STamp: 1649979945.787513
# Corners not found
# STamp: 1649979946.687596
# Corners not found
# STamp: 1649979947.63824
# Corners not found
# STamp: 1649979948.538153
# Corners not found
# STamp: 1649979948.987607
# Corners not found
# STamp: 1649979950.037325
# Corners not found
# STamp: 1649979950.6378
# Corners not found
# STamp: 1649979951.838063
# Corners not found
# STamp: 1649979953.187041
# Corners not found
# STamp: 1649979954.086574
# Corners not found
# STamp: 1649979955.137531
# Corners not found
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[31], line 24
#      16 traj_path_015 = "/home/neural/multicamSLAM/results/isec_ground2/traj_015.txt"
#      18 # main(data_path,traj_path_15, k, dist, first_stamp )
#      19
#      20 # main(data_path,traj_path_1, k, dist, first_stamp )
#      21
#      22 # main(data_path,traj_path_156, k, dist, first_stamp )
# ---> 24 main(data_path,traj_path_015, k, dist, first_stamp )
#
# Cell In[15], line 38, in main(data_path, traj_path, k, dist, first_stamp)
#      36             avg_rot_e = avg_rot_e + rot_e
#      37             cnt = cnt +1
# ---> 38 print("Average translation error : ", avg_trans_e/cnt)
#      39 print("Average rotational error : ", avg_rot_e/cnt)
#
# ZeroDivisionError: division by zero
